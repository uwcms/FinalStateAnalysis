# %%
import ROOT
from DataFormats.FWLite import Handle, Events
events = Events("/afs/cern.ch/work/t/truggles/Z_to_tautau/CMSSW_7_6_3_patch2/src/FinalStateAnalysis/NtupleTools/test/ntuplize7pat.root")
taus, tauLabel = Handle("std::vector<pat::Tau>"), "slimmedTaus"
mvas, mvaLabel = Handle("std::vector<pat::MET>"), "mvaMETTauTau"
for iev,event in enumerate(events):
    #print "Event:",iev`
    print "\nEvent %d: event %12d" % (iev, event.eventAuxiliary().event())
    #print "\nEvent %d: run %6d, lumi %4d, event %12d" % (iev,event.eventAuxiliary().run(), event.eventAuxiliary().luminosityBlock(),event.eventAuxiliary().event())
    event.getByLabel(tauLabel, taus)
    event.getByLabel(mvaLabel, mvas)
    for i,mva in enumerate(mvas.product()):
        print " - MvaMEt pt %f   MvaMet phi %f" % (mva.pt(), mva.phi())
        print " - userCand1: ",mva.userCand("lepton1")
        print " - userCand2: ",mva.userCand("lepton2")
    #mva.ls()
# Out:
# Event 0: event       985629
#
# Event 1: event       985630
#
# Event 2: event       985631
#  - MvaMEt pt 72.315147   MvaMet phi -2.979291
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - MvaMEt pt 64.626625   MvaMet phi 3.004933
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - MvaMEt pt 54.169846   MvaMet phi -2.613405
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#
# Event 3: event       985632
#
# Event 4: event       985633
#
# Event 5: event       985634
#
# Event 6: event       985635
#
# Event 7: event       985636
#  - MvaMEt pt 84.648300   MvaMet phi -3.041904
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - MvaMEt pt 77.714935   MvaMet phi -2.867761
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - MvaMEt pt 71.751694   MvaMet phi -3.036548
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#
# Event 8: event       985637
#  - MvaMEt pt 139.513245   MvaMet phi 2.922538
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fad50>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153eedc0>
#  - MvaMEt pt 120.650200   MvaMet phi 3.130761
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fad50>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153faea0>
#  - MvaMEt pt 161.092178   MvaMet phi 2.976196
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e10d0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f12b0>
#  - MvaMEt pt 103.186813   MvaMet phi 2.964331
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153eedc0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153faea0>
#  - MvaMEt pt 163.000107   MvaMet phi 2.964005
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fadc0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15378500>
#  - MvaMEt pt 156.356674   MvaMet phi 3.076011
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fae30>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f12b0>
#  - MvaMEt pt 106.546669   MvaMet phi 2.948807
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fad50>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15378500>
#  - MvaMEt pt 166.344757   MvaMet phi 2.987594
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153faea0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fae30>
#  - MvaMEt pt 158.766022   MvaMet phi 3.108556
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f12b0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fad50>
#  - MvaMEt pt 154.484421   MvaMet phi 3.109841
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15378500>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153faea0>
#
# Event 9: event       985638
#  - MvaMEt pt 23.682768   MvaMet phi 1.766335
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - MvaMEt pt 11.992533   MvaMet phi -3.046985
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - MvaMEt pt 35.462879   MvaMet phi 2.373649
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#
# Event 10: event       985639
#
# Event 11: event       985640
#  - MvaMEt pt 3.981101   MvaMet phi 1.783022
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - MvaMEt pt 31.680195   MvaMet phi -0.584331
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe3d0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 38.864185   MvaMet phi 2.040992
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138cd680>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe3d0>
#
# Event 12: event       985641
#
# Event 13: event       985642
#  - MvaMEt pt 24.799900   MvaMet phi 2.032801
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#
# Event 14: event       985643
#  - MvaMEt pt 26.687363   MvaMet phi 0.187552
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x110f0570>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#
# Event 15: event       985644
#
# Event 16: event       985645
#  - MvaMEt pt 5.714509   MvaMet phi 0.419764
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#
# Event 17: event       985646
#  - MvaMEt pt 17.634073   MvaMet phi -1.727309
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138cd680>
#
# Event 18: event       985647
#  - MvaMEt pt 15.018795   MvaMet phi -1.641401
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - MvaMEt pt 44.585072   MvaMet phi -2.103430
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 46.047680   MvaMet phi -2.174502
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - MvaMEt pt 16.384647   MvaMet phi -1.607483
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 22.978540   MvaMet phi -1.638558
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - MvaMEt pt 42.868004   MvaMet phi -2.193471
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#
# Event 19: event       985648
#
# Event 20: event       985649
#
# Event 21: event       985650
#  - MvaMEt pt 21.158712   MvaMet phi 1.188137
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153eee70>
#
# Event 22: event       985651
#  - MvaMEt pt 7.068960   MvaMet phi 1.553169
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#
# Event 23: event       985652
#
# Event 24: event       985653
#
# Event 25: event       985654
#  - MvaMEt pt 18.948368   MvaMet phi -1.233180
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15404e20>
#
# Event 26: event       985655
#
# Event 27: event       985656
#  - MvaMEt pt 11.344780   MvaMet phi 0.722666
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#
# Event 28: event       985657
#
# Event 29: event       985658
#
# Event 30: event       985659
#  - MvaMEt pt 7.056107   MvaMet phi -2.234926
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x110f0570>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153eee70>
#
# Event 31: event       985660
#
# Event 32: event       985661
#
# Event 33: event       985662
#
# Event 34: event       985663
#
# Event 35: event       985664
#  - MvaMEt pt 37.624706   MvaMet phi 1.440928
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x110f0570>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15404e20>
#
# Event 36: event       985665
#
# Event 37: event       985666
#
# Event 38: event       985667
#  - MvaMEt pt 96.362518   MvaMet phi 1.579914
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1540c790>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 98.663666   MvaMet phi 1.437550
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 106.583267   MvaMet phi 1.588615
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 92.875694   MvaMet phi 1.337143
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15402610>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 105.475784   MvaMet phi 1.528459
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1540c790>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - MvaMEt pt 108.871750   MvaMet phi 1.488359
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138e0df0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#
# Event 39: event       985668
#
# Event 40: event       985669
#
# Event 41: event       985670
#
# Event 42: event       985671
#
# Event 43: event       985672
#  - MvaMEt pt 52.066475   MvaMet phi 0.899766
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#
# Event 44: event       985673
#
# Event 45: event       985674
#  - MvaMEt pt 47.376820   MvaMet phi -2.438711
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x110f0570>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138cd680>
#
# Event 46: event       985675
#
# Event 47: event       985676
#
# Event 48: event       985677
#
# Event 49: event       985678
#
# Event 50: event       985679
#
# Event 51: event       985680
#
# Event 52: event       985681
#  - MvaMEt pt 31.106924   MvaMet phi 3.026335
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - MvaMEt pt 40.940651   MvaMet phi -3.093402
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x110f0570>
#  - MvaMEt pt 31.886677   MvaMet phi -2.540843
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#
# Event 53: event       985682
#  - MvaMEt pt 16.701435   MvaMet phi -0.668622
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#
# Event 54: event       985683
#  - MvaMEt pt 25.138599   MvaMet phi 2.781040
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#
# Event 55: event       985684
#  - MvaMEt pt 7.732324   MvaMet phi 1.286706
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#
# Event 56: event       985685
#  - MvaMEt pt 19.385103   MvaMet phi 1.053488
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138cd680>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138b4f70>
#
# Event 57: event       985686
#
# Event 58: event       985687
#
# Event 59: event       985688
#  - MvaMEt pt 21.637922   MvaMet phi -0.824770
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#
# Event 60: event       985689
#  - MvaMEt pt 8.815414   MvaMet phi -2.752911
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15401210>
#
# Event 61: event       985690
#
# Event 62: event       985691
#  - MvaMEt pt 59.231606   MvaMet phi 1.948171
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421530>
#  - MvaMEt pt 60.427860   MvaMet phi 2.047943
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#  - MvaMEt pt 39.970791   MvaMet phi 2.120511
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15402610>
#  - MvaMEt pt 65.485229   MvaMet phi 2.156793
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421530>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421470>
#  - MvaMEt pt 42.462517   MvaMet phi 2.115571
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - MvaMEt pt 64.454712   MvaMet phi 2.233593
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15402610>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#
# Event 63: event       985692
#  - MvaMEt pt 38.264065   MvaMet phi 0.764622
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d1650>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - MvaMEt pt 53.530785   MvaMet phi 0.582378
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421470>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#  - MvaMEt pt 48.718159   MvaMet phi 0.676669
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d2e40>
#
# Event 64: event       985693
#
# Event 65: event       985694
#
# Event 66: event       985695
#
# Event 67: event       985696
#
# Event 68: event       985697
#
# Event 69: event       985698
#
# Event 70: event       985699
#  - MvaMEt pt 39.281479   MvaMet phi 0.679039
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15402610>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#
# Event 71: event       985700
#
# Event 72: event       985701
#
# Event 73: event       985702
#  - MvaMEt pt 52.658749   MvaMet phi -3.072775
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1540c790>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138cd680>
#
# Event 74: event       985703
#
# Event 75: event       985704
#  - MvaMEt pt 162.165558   MvaMet phi -1.645259
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15402610>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1540c790>
#  - MvaMEt pt 163.718323   MvaMet phi -1.702362
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15404e20>
#  - MvaMEt pt 162.211304   MvaMet phi -1.606680
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153f5760>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421530>
#
# Event 76: event       985705
#  - MvaMEt pt 20.635750   MvaMet phi 2.895685
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x110f0570>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15424430>
#
# Event 77: event       985706
#
# Event 78: event       985707
#
# Event 79: event       985708
#  - MvaMEt pt 54.519978   MvaMet phi 1.955064
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15401210>
#  - MvaMEt pt 49.460491   MvaMet phi 2.406540
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421470>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x138d0410>
#  - MvaMEt pt 51.231998   MvaMet phi 1.675907
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15426ce0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421530>
#
# Event 80: event       985709
#
# Event 81: event       985710
#
# Event 82: event       985711
#
# Event 83: event       985712
#  - MvaMEt pt 7.284736   MvaMet phi -2.510315
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x154236f0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15423970>
#
# Event 84: event       985713
#  - MvaMEt pt 44.240547   MvaMet phi -2.673577
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1540c790>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#
# Event 85: event       985714
#
# Event 86: event       985715
#
# Event 87: event       985716
#
# Event 88: event       985717
#  - MvaMEt pt 27.433479   MvaMet phi 2.988177
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fb0b0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15426ce0>
#
# Event 89: event       985718
#  - MvaMEt pt 34.674835   MvaMet phi 0.239081
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1552f840>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15401210>
#
# Event 90: event       985719
#
# Event 91: event       985720
#
# Event 92: event       985721
#
# Event 93: event       985722
#
# Event 94: event       985723
#
# Event 95: event       985724
#  - MvaMEt pt 14.529954   MvaMet phi 2.744438
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15536060>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15401210>
#
# Event 96: event       985725
#
# Event 97: event       985726
#
# Event 98: event       985727
#  - MvaMEt pt 19.308720   MvaMet phi -0.340797
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15421470>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x15426ce0>
#
# Event 99: event       985728
#  - MvaMEt pt 24.280748   MvaMet phi -1.031662
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1552f840>
#
# Event 100: event       985729
#  - MvaMEt pt 22.739502   MvaMet phi 2.317314
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153fe6c0>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#
# Event 101: event       985730
#
# Event 102: event       985731
#  - MvaMEt pt 6.356752   MvaMet phi 1.295099
#  - userCand1:  <ROOT.edm::Ptr<reco::Candidate> object at 0x1552f840>
#  - userCand2:  <ROOT.edm::Ptr<reco::Candidate> object at 0x153d9a40>
#
# Event 103: event       985732
#
# Event 104: event       985733
# /afs/cern.ch/work/t/truggles/Z_to_tautau/CMSSW_7_6_3_patch2/src/FinalStateAnalysis/recipe/external/vpython/lib/python2.7/site-packages/ipykernel/__main__.py:12: RuntimeWarning: creating converter for unknown type "const char*const*"
